# %%
import numpy as np
g02 = -1.73597446
p02 = np.array([-1.91636694, -1.91146531, -1.73706901, -1.69998303, -1.69776225,
        -1.66063018, -1.63777532, -1.43146713, -1.43081045, -1.42337176,
        -1.42266794, -1.31964345, -1.28017809, -1.27918194, -1.2333454 ,
        -1.22060944, -1.21120615, -1.12297919, -1.118343  , -1.02264934,
        -1.00713053, -0.91013867, -0.91005855, -0.7918367 , -0.78471462,
        -0.78325518, -0.73897813])
print(p02[0])
# Out:
# -1.91636694

# %%
g04 =-1.60360665
p04 = [-1.92944238, -1.91889235, -1.74459817, -1.71885918, -1.71587182,
        -1.68425086, -1.63550777, -1.43173541, -1.43084521, -1.42414761,
        -1.42248344, -1.34416292, -1.27622635, -1.27429767, -1.23331884,
        -1.22001606, -1.21120565, -1.12297261, -1.11834055, -1.02526589,
        -0.99569881, -0.91010028, -0.9100907 , -0.77132298, -0.76911642,
        -0.76839147, -0.73966503]
print(p04[0])
# Out:
# -1.92944238

# %%
g06 = -1.49619275
p06 = [-1.93391681, -1.92069292, -1.74883394, -1.73126393, -1.72795589,
        -1.69541168, -1.63205501, -1.43117767, -1.4300022 , -1.42399653,
        -1.4216746 , -1.35531624, -1.27316771, -1.27057083, -1.23331693,
        -1.21973713, -1.21120553, -1.1229639 , -1.11834043, -1.02711465,
        -0.98676208, -0.91045179, -0.91024909, -0.76105654, -0.7582643 ,
        -0.75011717, -0.73997407]
print(p06[0])
# Out:
# -1.93391681

# %%
g08 = -1.40230099
p08 = [-1.93222189, -1.89314783, -1.77161472, -1.74392707, -1.73770759,
        -1.70040947, -1.63162903, -1.43044261, -1.4287557 , -1.42317409,
        -1.42037957, -1.33062143, -1.26722255, -1.26217536, -1.25771625,
        -1.23329708, -1.21119329, -1.12200259, -1.1183477 , -1.01684349,
        -0.94590221, -0.94183545, -0.88564178, -0.75263075, -0.72909825,
        -0.72171527, -0.71726819]
print(p08[0])
# Out:
# -1.93222189

# %%
g1 = -1.31599601
p1 = [-1.95321299, -1.90713459, -1.82463099, -1.79845808, -1.71630418,
        -1.68268828, -1.62884004, -1.43028354, -1.42791775, -1.42315875,
        -1.42020075, -1.32950925, -1.29877818, -1.29808162, -1.22387181,
        -1.21848804, -1.20840276, -1.16825497, -1.12165277, -1.11777219,
        -1.10279545, -1.03660693, -0.90983389, -0.90217042, -0.6592295 ,
        -0.47077329, -0.45147792]
print(p1[0])
# Out:
# -1.95321299

# %%
bfprob = (0.02, 0.04, 0.06, 0.08, 0.1)
p= np.array((p02[0], p04[0], p06[0], p08[0], p1[0]))
print(p)

g= np.array((g02, g04, g06, g08, g1))
print("with prob",g)
# Out:
# [-1.91636694 -1.92944238 -1.93391681 -1.93222189 -1.95321299]
# with prob [-1.73597446 -1.60360665 -1.49619275 -1.40230099 -1.31599601]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
uccsd = -1.951956244782695

plt.plot(bfprob, p, marker='v', linestyle='-', color='blue')
plt.plot(bfprob, g, marker='o', linestyle='--', color='black')
plt.axhline(y=uccsd, color='red', linestyle=':', label='FCI Ground State Energy')

plt.xlabel("Bit-Flip Probability")
plt.ylabel("Ground State Energy (Ha)")
plt.title("H4 sq Ground State Energy vs Bit-Flip Prob")
plt.legend(["qscEOM gr after bitflip in gr", "gr with bitflip", "UCCSD gr"], loc="center right")
#plt.grid(True)
plt.tight_layout()
plt.show()
